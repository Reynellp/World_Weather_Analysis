# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.0, 180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 720

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6af6a2b974791cdaeeb1fef2f4813a54

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
       
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_desc })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | mareeba
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | lavumisa
# Processing Record 5 of Set 1 | lampazos de naranjo
# Processing Record 6 of Set 1 | high level
# Processing Record 7 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | kenai
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | taihe
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | mwense
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | abu kamal
# Processing Record 21 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | los andes
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | birao
# Processing Record 26 of Set 1 | pontianak
# Processing Record 27 of Set 1 | omboue
# Processing Record 28 of Set 1 | puerto leguizamo
# Processing Record 29 of Set 1 | moctezuma
# Processing Record 30 of Set 1 | san jeronimo
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | paamiut
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | loncoche
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | wageningen
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | clermont
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | boulsa
# Processing Record 47 of Set 1 | pringsewu
# Processing Record 48 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | chistogorskiy
# Processing Record 2 of Set 2 | mbandaka
# Processing Record 3 of Set 2 | nouakchott
# Processing Record 4 of Set 2 | oranjestad
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 2 | roald
# Processing Record 8 of Set 2 | anadyr
# Processing Record 9 of Set 2 | agara
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | nikolskoye
# Processing Record 12 of Set 2 | rocha
# Processing Record 13 of Set 2 | weyburn
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | puerto baquerizo moreno
# Processing Record 19 of Set 2 | grootfontein
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | aklavik
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | almaznyy
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | busselton
# Processing Record 31 of Set 2 | phan thiet
# Processing Record 32 of Set 2 | chute-aux-outardes
# Processing Record 33 of Set 2 | zhigansk
# Processing Record 34 of Set 2 | sabinas hidalgo
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | mayahi
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | yamada
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | tingi
# Processing Record 43 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | moindou
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | port hedland
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | yilan
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | miri
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 3 | malaya vishera
# Processing Record 5 of Set 3 | buala
# Processing Record 6 of Set 3 | belmonte
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | przhevalskoye
# Processing Record 10 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 3 | carauari
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | ambilobe
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | gornopravdinsk
# Processing Record 19 of Set 3 | moranbah
# Processing Record 20 of Set 3 | ferme-neuve
# Processing Record 21 of Set 3 | diego de almagro
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | sapao
# City not found. Skipping...
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | padang
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | asau
# Processing Record 29 of Set 3 | finnsnes
# Processing Record 30 of Set 3 | byron bay
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | vestmannaeyjar
# Processing Record 33 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 3 | boende
# Processing Record 35 of Set 3 | aksarka
# Processing Record 36 of Set 3 | paracuru
# Processing Record 37 of Set 3 | coahuayana
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | palmeira
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | tanjong karang
# City not found. Skipping...
# Processing Record 42 of Set 3 | tailai
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | aswan
# Processing Record 46 of Set 3 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 3 | areosa
# Processing Record 48 of Set 3 | manga
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | pitimbu
# Processing Record 1 of Set 4 | krasnyy chikoy
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | champerico
# Processing Record 4 of Set 4 | calabozo
# Processing Record 5 of Set 4 | ust-maya
# Processing Record 6 of Set 4 | severnoye
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | atuona
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 4 | pacifica
# Processing Record 15 of Set 4 | waingapu
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | nouadhibou
# Processing Record 18 of Set 4 | verkhnevilyuysk
# Processing Record 19 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | pithiviers
# Processing Record 23 of Set 4 | xai-xai
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | raga
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | sholapur
# Processing Record 28 of Set 4 | dispur
# Processing Record 29 of Set 4 | lewistown
# Processing Record 30 of Set 4 | beringovskiy
# Processing Record 31 of Set 4 | pangnirtung
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | lakhipur
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | bella union
# Processing Record 36 of Set 4 | hoquiam
# Processing Record 37 of Set 4 | muisne
# Processing Record 38 of Set 4 | kharp
# Processing Record 39 of Set 4 | tucupita
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | yellowknife
# Processing Record 42 of Set 4 | merauke
# Processing Record 43 of Set 4 | bougouni
# Processing Record 44 of Set 4 | comodoro rivadavia
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | matara
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | ube
# Processing Record 49 of Set 4 | yuksekova
# Processing Record 50 of Set 4 | svetlogorsk
# Processing Record 1 of Set 5 | bindi
# Processing Record 2 of Set 5 | linxia
# Processing Record 3 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 5 | belle fourche
# Processing Record 5 of Set 5 | sokolo
# Processing Record 6 of Set 5 | daru
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | faanui
# Processing Record 9 of Set 5 | oak ridge
# Processing Record 10 of Set 5 | san jose
# Processing Record 11 of Set 5 | isla mujeres
# Processing Record 12 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 5 | aykhal
# Processing Record 14 of Set 5 | nampula
# Processing Record 15 of Set 5 | paita
# Processing Record 16 of Set 5 | vanavara
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | kurtalan
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | karmana
# City not found. Skipping...
# Processing Record 21 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | luanda
# Processing Record 23 of Set 5 | aksu
# Processing Record 24 of Set 5 | corn island
# Processing Record 25 of Set 5 | kedrovyy
# Processing Record 26 of Set 5 | sioux lookout
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | kasempa
# Processing Record 31 of Set 5 | kismayo
# Processing Record 32 of Set 5 | nichinan
# Processing Record 33 of Set 5 | darnah
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | quime
# Processing Record 36 of Set 5 | faya
# Processing Record 37 of Set 5 | motta di livenza
# Processing Record 38 of Set 5 | ada
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | miles city
# Processing Record 44 of Set 5 | hovd
# Processing Record 45 of Set 5 | we
# City not found. Skipping...
# Processing Record 46 of Set 5 | gondal
# Processing Record 47 of Set 5 | tariba
# Processing Record 48 of Set 5 | gazanjyk
# Processing Record 49 of Set 5 | sinnamary
# Processing Record 50 of Set 5 | manicore
# Processing Record 1 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 6 | ketchikan
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | amahai
# Processing Record 5 of Set 6 | honningsvag
# Processing Record 6 of Set 6 | mao
# Processing Record 7 of Set 6 | urumqi
# Processing Record 8 of Set 6 | east london
# Processing Record 9 of Set 6 | coos bay
# Processing Record 10 of Set 6 | quatre cocos
# Processing Record 11 of Set 6 | mancio lima
# Processing Record 12 of Set 6 | akyab
# Processing Record 13 of Set 6 | eenhana
# Processing Record 14 of Set 6 | bethel
# Processing Record 15 of Set 6 | riverton
# Processing Record 16 of Set 6 | grand gaube
# Processing Record 17 of Set 6 | lakeland
# Processing Record 18 of Set 6 | etawah
# Processing Record 19 of Set 6 | zalantun
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | clearwater
# Processing Record 22 of Set 6 | hilo
# Processing Record 23 of Set 6 | hingorja
# Processing Record 24 of Set 6 | winnemucca
# Processing Record 25 of Set 6 | tingo maria
# Processing Record 26 of Set 6 | gari
# Processing Record 27 of Set 6 | kuloy
# Processing Record 28 of Set 6 | araxa
# Processing Record 29 of Set 6 | charters towers
# Processing Record 30 of Set 6 | buraydah
# Processing Record 31 of Set 6 | brenham
# Processing Record 32 of Set 6 | palakkad
# Processing Record 33 of Set 6 | kusa
# Processing Record 34 of Set 6 | iracoubo
# Processing Record 35 of Set 6 | zlynka
# Processing Record 36 of Set 6 | kano
# Processing Record 37 of Set 6 | mattru
# Processing Record 38 of Set 6 | linguere
# Processing Record 39 of Set 6 | mizan teferi
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | kampong thum
# Processing Record 42 of Set 6 | vila
# Processing Record 43 of Set 6 | tura
# Processing Record 44 of Set 6 | deputatskiy
# Processing Record 45 of Set 6 | tiksi
# Processing Record 46 of Set 6 | moerai
# Processing Record 47 of Set 6 | lahad datu
# Processing Record 48 of Set 6 | jurado
# Processing Record 49 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 50 of Set 6 | artyom
# Processing Record 1 of Set 7 | koshurnikovo
# Processing Record 2 of Set 7 | coutances
# Processing Record 3 of Set 7 | qinhuangdao
# Processing Record 4 of Set 7 | carnarvon
# Processing Record 5 of Set 7 | puerto carreno
# Processing Record 6 of Set 7 | mikkeli
# Processing Record 7 of Set 7 | mumford
# Processing Record 8 of Set 7 | doume
# Processing Record 9 of Set 7 | yelabuga
# Processing Record 10 of Set 7 | ingham
# Processing Record 11 of Set 7 | georgetown
# Processing Record 12 of Set 7 | maamba
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | manzanillo
# Processing Record 17 of Set 7 | asmara
# Processing Record 18 of Set 7 | sun valley
# Processing Record 19 of Set 7 | neftcala
# Processing Record 20 of Set 7 | tual
# Processing Record 21 of Set 7 | ligayan
# Processing Record 22 of Set 7 | chapais
# Processing Record 23 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 7 | porto novo
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | esperance
# Processing Record 27 of Set 7 | te anau
# Processing Record 28 of Set 7 | ennis
# Processing Record 29 of Set 7 | tonantins
# Processing Record 30 of Set 7 | cidreira
# Processing Record 31 of Set 7 | victoria
# Processing Record 32 of Set 7 | nyurba
# Processing Record 33 of Set 7 | pithora
# Processing Record 34 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 7 | katsuura
# Processing Record 36 of Set 7 | seoul
# Processing Record 37 of Set 7 | bedford
# Processing Record 38 of Set 7 | simao
# Processing Record 39 of Set 7 | dom pedro
# Processing Record 40 of Set 7 | solnechnyy
# Processing Record 41 of Set 7 | donetsk
# Processing Record 42 of Set 7 | northam
# Processing Record 43 of Set 7 | ilulissat
# Processing Record 44 of Set 7 | tarakan
# Processing Record 45 of Set 7 | pimenta bueno
# Processing Record 46 of Set 7 | havre-saint-pierre
# Processing Record 47 of Set 7 | velikovechnoye
# Processing Record 48 of Set 7 | lixourion
# Processing Record 49 of Set 7 | north bend
# Processing Record 50 of Set 7 | ndele
# Processing Record 1 of Set 8 | shestakovo
# Processing Record 2 of Set 8 | naze
# Processing Record 3 of Set 8 | tabou
# Processing Record 4 of Set 8 | port lincoln
# Processing Record 5 of Set 8 | yumen
# Processing Record 6 of Set 8 | saldanha
# Processing Record 7 of Set 8 | kisangani
# Processing Record 8 of Set 8 | sanghar
# Processing Record 9 of Set 8 | nioro
# Processing Record 10 of Set 8 | dubbo
# Processing Record 11 of Set 8 | kruisfontein
# Processing Record 12 of Set 8 | araouane
# Processing Record 13 of Set 8 | nome
# Processing Record 14 of Set 8 | port augusta
# Processing Record 15 of Set 8 | sao filipe
# Processing Record 16 of Set 8 | sitka
# Processing Record 17 of Set 8 | honiara
# Processing Record 18 of Set 8 | suna
# Processing Record 19 of Set 8 | kanalia
# Processing Record 20 of Set 8 | varazze
# Processing Record 21 of Set 8 | am timan
# Processing Record 22 of Set 8 | usinsk
# Processing Record 23 of Set 8 | cizre
# Processing Record 24 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 8 | porto belo
# Processing Record 26 of Set 8 | mangualde
# Processing Record 27 of Set 8 | san quintin
# Processing Record 28 of Set 8 | cleburne
# Processing Record 29 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 8 | tadine
# Processing Record 31 of Set 8 | tsabong
# Processing Record 32 of Set 8 | da lat
# Processing Record 33 of Set 8 | black river
# Processing Record 34 of Set 8 | nueva loja
# Processing Record 35 of Set 8 | kajaani
# Processing Record 36 of Set 8 | cap malheureux
# Processing Record 37 of Set 8 | stromness
# Processing Record 38 of Set 8 | longyearbyen
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | san lorenzo
# Processing Record 41 of Set 8 | airai
# Processing Record 42 of Set 8 | sisimiut
# Processing Record 43 of Set 8 | kavieng
# Processing Record 44 of Set 8 | domoni
# Processing Record 45 of Set 8 | cockburn town
# Processing Record 46 of Set 8 | bubaque
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | komsomolskiy
# Processing Record 49 of Set 8 | soyo
# Processing Record 50 of Set 8 | sorkjosen
# Processing Record 1 of Set 9 | erzin
# Processing Record 2 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 3 of Set 9 | saharsa
# Processing Record 4 of Set 9 | huaraz
# Processing Record 5 of Set 9 | whitehorse
# Processing Record 6 of Set 9 | malakal
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | gannan
# Processing Record 9 of Set 9 | niksic
# Processing Record 10 of Set 9 | bahia blanca
# Processing Record 11 of Set 9 | inuvik
# Processing Record 12 of Set 9 | pisco
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | roros
# Processing Record 15 of Set 9 | laguna
# Processing Record 16 of Set 9 | kutum
# Processing Record 17 of Set 9 | husavik
# Processing Record 18 of Set 9 | iqaluit
# Processing Record 19 of Set 9 | nizhniy tsasuchey
# Processing Record 20 of Set 9 | dawei
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | toba
# Processing Record 23 of Set 9 | baruun-urt
# Processing Record 24 of Set 9 | hita
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | camocim
# Processing Record 27 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 30 of Set 9 | poronaysk
# Processing Record 31 of Set 9 | jalu
# Processing Record 32 of Set 9 | tevaitoa
# Processing Record 33 of Set 9 | yulara
# Processing Record 34 of Set 9 | holme
# Processing Record 35 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 9 | zhanaozen
# Processing Record 37 of Set 9 | qaqortoq
# Processing Record 38 of Set 9 | xifeng
# Processing Record 39 of Set 9 | santiago de cao
# Processing Record 40 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 41 of Set 9 | santander
# Processing Record 42 of Set 9 | krasnoselkup
# Processing Record 43 of Set 9 | maceio
# Processing Record 44 of Set 9 | kongolo
# Processing Record 45 of Set 9 | balkhash
# Processing Record 46 of Set 9 | tautira
# Processing Record 47 of Set 9 | tigre
# Processing Record 48 of Set 9 | walvis bay
# Processing Record 49 of Set 9 | batangafo
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 10 | ossora
# Processing Record 3 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 10 | valparaiso
# Processing Record 5 of Set 10 | broome
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | amiens
# Processing Record 8 of Set 10 | dingle
# Processing Record 9 of Set 10 | badulla
# Processing Record 10 of Set 10 | kuytun
# Processing Record 11 of Set 10 | barcelos
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | mlandizi
# Processing Record 14 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 15 of Set 10 | kyshtovka
# Processing Record 16 of Set 10 | nuevo progreso
# Processing Record 17 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 10 | amparafaravola
# Processing Record 19 of Set 10 | dudinka
# Processing Record 20 of Set 10 | upernavik
# Processing Record 21 of Set 10 | bayshore gardens
# Processing Record 22 of Set 10 | denizli
# Processing Record 23 of Set 10 | lagoa
# Processing Record 24 of Set 10 | westport
# Processing Record 25 of Set 10 | ballina
# Processing Record 26 of Set 10 | yinchuan
# Processing Record 27 of Set 10 | sorland
# Processing Record 28 of Set 10 | mahon
# Processing Record 29 of Set 10 | baherden
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | ewa beach
# Processing Record 32 of Set 10 | doka
# Processing Record 33 of Set 10 | sorong
# Processing Record 34 of Set 10 | yermakovskoye
# Processing Record 35 of Set 10 | xinxiang
# Processing Record 36 of Set 10 | kapoeta
# Processing Record 37 of Set 10 | beaufort
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 40 of Set 10 | shenjiamen
# Processing Record 41 of Set 10 | chanika
# Processing Record 42 of Set 10 | leshukonskoye
# Processing Record 43 of Set 10 | avera
# Processing Record 44 of Set 10 | corinto
# Processing Record 45 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 46 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 10 | boa vista
# Processing Record 48 of Set 10 | thinadhoo
# Processing Record 49 of Set 10 | sabang
# Processing Record 50 of Set 10 | lake havasu city
# Processing Record 1 of Set 11 | isangel
# Processing Record 2 of Set 11 | pierre
# Processing Record 3 of Set 11 | bastia
# Processing Record 4 of Set 11 | vao
# Processing Record 5 of Set 11 | cuxhaven
# Processing Record 6 of Set 11 | mogadishu
# Processing Record 7 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 11 | russell
# Processing Record 9 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 10 of Set 11 | sao gabriel da cachoeira
# Processing Record 11 of Set 11 | narsaq
# Processing Record 12 of Set 11 | hofgeismar
# Processing Record 13 of Set 11 | barguzin
# Processing Record 14 of Set 11 | akdepe
# Processing Record 15 of Set 11 | areia branca
# Processing Record 16 of Set 11 | jumla
# Processing Record 17 of Set 11 | lusambo
# Processing Record 18 of Set 11 | russkaya polyana
# Processing Record 19 of Set 11 | caconda
# Processing Record 20 of Set 11 | ambatondrazaka
# Processing Record 21 of Set 11 | provideniya
# Processing Record 22 of Set 11 | mulanur
# Processing Record 23 of Set 11 | rawson
# Processing Record 24 of Set 11 | quimper
# Processing Record 25 of Set 11 | huarmey
# Processing Record 26 of Set 11 | harsud
# Processing Record 27 of Set 11 | jawa
# Processing Record 28 of Set 11 | vredendal
# Processing Record 29 of Set 11 | alamosa
# Processing Record 30 of Set 11 | gorontalo
# Processing Record 31 of Set 11 | bilma
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | lithakia
# Processing Record 34 of Set 11 | hostotipaquillo
# Processing Record 35 of Set 11 | havoysund
# Processing Record 36 of Set 11 | toul
# Processing Record 37 of Set 11 | panlaitan
# Processing Record 38 of Set 11 | chirongui
# Processing Record 39 of Set 11 | kalulushi
# Processing Record 40 of Set 11 | upington
# Processing Record 41 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 11 | merritt
# Processing Record 43 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 44 of Set 11 | kautokeino
# Processing Record 45 of Set 11 | udachnyy
# Processing Record 46 of Set 11 | terre-de-bas
# Processing Record 47 of Set 11 | zhirnovsk
# Processing Record 48 of Set 11 | marsa matruh
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | batagay
# Processing Record 1 of Set 12 | sulecin
# Processing Record 2 of Set 12 | newport
# Processing Record 3 of Set 12 | gulbene
# Processing Record 4 of Set 12 | tete
# Processing Record 5 of Set 12 | rockhampton
# Processing Record 6 of Set 12 | ozernovskiy
# Processing Record 7 of Set 12 | hope
# Processing Record 8 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | kidal
# Processing Record 10 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 12 | fairbanks
# Processing Record 12 of Set 12 | garowe
# Processing Record 13 of Set 12 | delijan
# Processing Record 14 of Set 12 | kodinsk
# Processing Record 15 of Set 12 | estelle
# Processing Record 16 of Set 12 | lexington
# Processing Record 17 of Set 12 | yar-sale
# Processing Record 18 of Set 12 | broken hill
# Processing Record 19 of Set 12 | port hawkesbury
# Processing Record 20 of Set 12 | machilipatnam
# Processing Record 21 of Set 12 | celestun
# Processing Record 22 of Set 12 | neosho
# Processing Record 23 of Set 12 | hamilton
# Processing Record 24 of Set 12 | ndola
# Processing Record 25 of Set 12 | bambanglipuro
# Processing Record 26 of Set 12 | oktyabrskiy
# Processing Record 27 of Set 12 | lacarak
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | sawakin
# Processing Record 30 of Set 12 | severo-kurilsk
# Processing Record 31 of Set 12 | aquiraz
# Processing Record 32 of Set 12 | agira
# Processing Record 33 of Set 12 | denpasar
# Processing Record 34 of Set 12 | chakia
# Processing Record 35 of Set 12 | emba
# Processing Record 36 of Set 12 | conde
# Processing Record 37 of Set 12 | minsk
# Processing Record 38 of Set 12 | leh
# Processing Record 39 of Set 12 | vostok
# Processing Record 40 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 12 | midland
# Processing Record 42 of Set 12 | la ronge
# Processing Record 43 of Set 12 | stornoway
# Processing Record 44 of Set 12 | sfantu gheorghe
# Processing Record 45 of Set 12 | cadillac
# Processing Record 46 of Set 12 | alta floresta
# Processing Record 47 of Set 12 | culasi
# Processing Record 48 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 12 | jacareacanga
# Processing Record 50 of Set 12 | sotouboua
# Processing Record 1 of Set 13 | juybar
# Processing Record 2 of Set 13 | moussoro
# Processing Record 3 of Set 13 | tigil
# Processing Record 4 of Set 13 | harindanga
# Processing Record 5 of Set 13 | ojinaga
# Processing Record 6 of Set 13 | richards bay
# Processing Record 7 of Set 13 | biu
# Processing Record 8 of Set 13 | xining
# Processing Record 9 of Set 13 | inhambane
# Processing Record 10 of Set 13 | altay
# Processing Record 11 of Set 13 | cardoso
# Processing Record 12 of Set 13 | salalah
# Processing Record 13 of Set 13 | burica
# City not found. Skipping...
# Processing Record 14 of Set 13 | ayni
# Processing Record 15 of Set 13 | vestmanna
# Processing Record 16 of Set 13 | pribelskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | lavrentiya
# Processing Record 18 of Set 13 | hanna
# Processing Record 19 of Set 13 | aguimes
# Processing Record 20 of Set 13 | vila do maio
# Processing Record 21 of Set 13 | visnes
# Processing Record 22 of Set 13 | mawlaik
# Processing Record 23 of Set 13 | naushki
# Processing Record 24 of Set 13 | maldonado
# Processing Record 25 of Set 13 | chinu
# Processing Record 26 of Set 13 | san cristobal
# Processing Record 27 of Set 13 | chicama
# Processing Record 28 of Set 13 | carnduff
# Processing Record 29 of Set 13 | menongue
# Processing Record 30 of Set 13 | kununurra
# Processing Record 31 of Set 13 | kloulklubed
# Processing Record 32 of Set 13 | kamenka
# Processing Record 33 of Set 13 | dakar
# Processing Record 34 of Set 13 | moose factory
# Processing Record 35 of Set 13 | kondinskoye
# Processing Record 36 of Set 13 | werther
# Processing Record 37 of Set 13 | tchaourou
# Processing Record 38 of Set 13 | opuwo
# Processing Record 39 of Set 13 | itapirapua
# Processing Record 40 of Set 13 | taveta
# Processing Record 41 of Set 13 | lujan
# Processing Record 42 of Set 13 | rodino
# Processing Record 43 of Set 13 | shimoda
# Processing Record 44 of Set 13 | yurya
# City not found. Skipping...
# Processing Record 45 of Set 13 | miranpur
# Processing Record 46 of Set 13 | itarema
# Processing Record 47 of Set 13 | san luis
# Processing Record 48 of Set 13 | mayumba
# Processing Record 49 of Set 13 | saint-pierre
# Processing Record 50 of Set 13 | vary
# Processing Record 1 of Set 14 | mehamn
# Processing Record 2 of Set 14 | urengoy
# Processing Record 3 of Set 14 | biak
# Processing Record 4 of Set 14 | zhangye
# Processing Record 5 of Set 14 | garmsar
# Processing Record 6 of Set 14 | sydney
# Processing Record 7 of Set 14 | thunder bay
# Processing Record 8 of Set 14 | buchanan
# Processing Record 9 of Set 14 | okhotsk
# Processing Record 10 of Set 14 | flinders
# Processing Record 11 of Set 14 | lata
# Processing Record 12 of Set 14 | magaramkent
# Processing Record 13 of Set 14 | sobolevo
# Processing Record 14 of Set 14 | acapulco
# Processing Record 15 of Set 14 | kaseda
# Processing Record 16 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 14 | nuuk
# Processing Record 18 of Set 14 | finschhafen
# Processing Record 19 of Set 14 | port antonio
# Processing Record 20 of Set 14 | sterling
# Processing Record 21 of Set 14 | halifax
# Processing Record 22 of Set 14 | fereydun kenar
# Processing Record 23 of Set 14 | poso
# Processing Record 24 of Set 14 | kargopol
# Processing Record 25 of Set 14 | sukabumi
# Processing Record 26 of Set 14 | whitecourt
# Processing Record 27 of Set 14 | ilkeston
# Processing Record 28 of Set 14 | conceicao das alagoas
# Processing Record 29 of Set 14 | beloha
# Processing Record 30 of Set 14 | tanout
# Processing Record 31 of Set 14 | caaguazu
# Processing Record 32 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 14 | pundaguitan
# Processing Record 34 of Set 14 | ovalle
# Processing Record 35 of Set 14 | atka
# City not found. Skipping...
# Processing Record 36 of Set 14 | mandalgovi
# Processing Record 37 of Set 14 | filingue
# Processing Record 38 of Set 14 | gavrilovka vtoraya
# Processing Record 39 of Set 14 | sabha
# Processing Record 40 of Set 14 | novo oriente
# Processing Record 41 of Set 14 | paoua
# Processing Record 42 of Set 14 | namatanai
# Processing Record 43 of Set 14 | diamantino
# Processing Record 44 of Set 14 | preobrazheniye
# Processing Record 45 of Set 14 | monte alegre
# Processing Record 46 of Set 14 | fershampenuaz
# Processing Record 47 of Set 14 | sola
# Processing Record 48 of Set 14 | naryan-mar
# Processing Record 49 of Set 14 | port-cartier
# Processing Record 50 of Set 14 | ilhabela
# Processing Record 1 of Set 15 | alibag
# Processing Record 2 of Set 15 | otane
# Processing Record 3 of Set 15 | kaniama
# Processing Record 4 of Set 15 | koutsouras
# Processing Record 5 of Set 15 | tucuman
# Processing Record 6 of Set 15 | bairiki
# Processing Record 7 of Set 15 | ekhabi
# Processing Record 8 of Set 15 | jieshi
# Processing Record 9 of Set 15 | labuhan
# Processing Record 10 of Set 15 | moron
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | mecca
# Processing Record 13 of Set 15 | dwarka
# Processing Record 14 of Set 15 | santa cruz
# Processing Record 15 of Set 15 | matagami
# Processing Record 16 of Set 15 | chabahar
# Processing Record 17 of Set 15 | flin flon
# Processing Record 18 of Set 15 | lompoc
# Processing Record 19 of Set 15 | riachao das neves
# Processing Record 20 of Set 15 | yatou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 659

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Norman Wells      CA  65.2820 -126.8329      8.64        78
# 1              Mareeba      AU -17.0000  145.4333     74.44        98
# 2               Avarua      CK -21.2078 -159.7750     82.45        83
# 3             Lavumisa      SZ -27.3100   31.8920     67.30        97
# 4  Lampazos De Naranjo      MX  27.0167 -100.5167     87.85        14
# 5           High Level      CA  58.5169 -117.1360     14.11       100
# 6               Barrow      US  71.2906 -156.7887      3.22        85
# 7                Kenai      US  60.5544 -151.2583     33.85        90
# 8         Punta Arenas      CL -53.1500  -70.9167     51.91        50
# 9                Kapaa      US  22.0752 -159.3190     80.92        78
#
#    Cloudiness  Wind Speed                 Date Current Description
# 0          75       16.11  2023-01-02 21:23:18       broken clouds
# 1         100        2.39  2023-01-02 21:23:18     overcast clouds
# 2          75        9.22  2023-01-02 21:23:19          light rain
# 3          14        1.72  2023-01-02 21:23:19          few clouds
# 4           1        6.49  2023-01-02 21:23:19           clear sky
# 5          40        2.30  2023-01-02 21:23:20    scattered clouds
# 6         100       21.85  2023-01-02 21:23:21     overcast clouds
# 7          75        5.75  2023-01-02 21:23:21       broken clouds
# 8           0       37.98  2023-01-02 21:23:22           clear sky
# 9         100        8.05  2023-01-02 21:23:22     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Date                    object
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data = "weatherPy_data.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data, index_label="City_ID")
